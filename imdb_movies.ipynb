# %%
import pandas as pd 
import numpy as np

# %%
df =pd.read_csv('IMDB-Movie-Data.csv')

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
display(type(df))
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df.duplicated()
#no duplicates in the data frame
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.set_index('Title',inplace=True)

# %%
df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
df.loc['Suicide Squad','Rank']
# Out:
# 5

# %%
df.iloc[5]
# Out:
# Rank                                                                  6
# Genre                                          Action,Adventure,Fantasy
# Description           European mercenaries searching for black powde...
# Director                                                    Yimou Zhang
# Actors                    Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# Year                                                               2016
# Runtime (Minutes)                                                   103
# Rating                                                              6.1
# Votes                                                             56036
# Revenue (Millions)                                                45.13
# Metascore                                                          42.0
# Name: The Great Wall, dtype: object

# %%
df_new =df[['Rank','Genre']]

# %%
df_new #the index will show up with any subset you choose
# Out:
#                          Rank                     Genre
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
# [1000 rows x 2 columns]

# %%
df_nums=df.select_dtypes(include=['int64','float64'])

# %%
df_nums
# Out:
#                          Rank  Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy     1  2014                121     8.1  757074
# Prometheus                  2  2012                124     7.0  485820
# Split                       3  2016                117     7.3  157606
# Sing                        4  2016                108     7.2   60545
# Suicide Squad               5  2016                123     6.2  393727
# ...                       ...   ...                ...     ...     ...
# Secret in Their Eyes      996  2015                111     6.2   27585
# Hostel: Part II           997  2007                 94     5.5   73152
# Step Up 2: The Streets    998  2008                 98     6.2   70699
# Search Party              999  2014                 93     5.6    4881
# Nine Lives               1000  2016                 87     5.3   12435
#
#                          Revenue (Millions)  Metascore
# Title
# ...

# %%
df_strs=df.select_dtypes(include=['object'])

# %%
df_strs
# Out:
#                                             Genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 126.0+ KB

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 126.0+ KB

# %%
df_new=df
df_copy=df.copy()

# %%
df.dropna(axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Genre               838 non-null    object
#  2   Description         838 non-null    object
#  3   Director            838 non-null    object
#  4   Actors              838 non-null    object
#  5   Year                838 non-null    int64
#  6   Runtime (Minutes)   838 non-null    int64
#  7   Rating              838 non-null    float64
#  8   Votes               838 non-null    int64
#  9   Revenue (Millions)  838 non-null    float64
#  10  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 78.6+ KB

# %%
df_new.info() # making df_new = df makes the changes on both
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 838 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                838 non-null    int64
#  1   Genre               838 non-null    object
#  2   Description         838 non-null    object
#  3   Director            838 non-null    object
#  4   Actors              838 non-null    object
#  5   Year                838 non-null    int64
#  6   Runtime (Minutes)   838 non-null    int64
#  7   Rating              838 non-null    float64
#  8   Votes               838 non-null    int64
#  9   Revenue (Millions)  838 non-null    float64
#  10  Metascore           838 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 78.6+ KB

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df_copy.fillna(df_copy['Revenue (Millions)'].mean(),inplace=True)
#filling the null value with the most reapted one

# %%
df_copy.info()
#filled all null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  1000 non-null   float64
#  10  Metascore           1000 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 126.0+ KB

# %%
df
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
james=df[df['Director']=='James Gunn']
james
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
# Slither                   909     Comedy,Horror,Sci-Fi
# Super                     938             Comedy,Drama
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Slither                  A small town is taken over by an alien plague,...
# Super                    After his wife falls under the influence of a ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
# Slither                  James Gunn
# Super                    James Gunn
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Slither                  Nathan Fillion, Elizabeth Banks, Michael Rooke...
# ...

# %%
riddely_chris=df[(df['Director']=='Ridley Scott') | (df['Director']=='Christopher Nolan')]
riddely_chris
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# Interstellar              37    Adventure,Drama,Sci-Fi
# The Dark Knight           55        Action,Crime,Drama
# The Prestige              65      Drama,Mystery,Sci-Fi
# Inception                 81   Action,Adventure,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# The Dark Knight Rises    125           Action,Thriller
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# ...

# %%
riddely_chris.shape
# Out:
# (13, 11)

# %%
df_movies_special = df[((df['Year'] >= 2005) & (df['Year'] <= 2008 ) & (df['Rating'] >= 8) & (df['Revenue (Millions)'] <= df['Revenue (Millions)'].quantile(.25)))]
df_movies_special
# Out:
#                      Rank               Genre  \
# Title
# The Lives of Others   477      Drama,Thriller
# Taare Zameen Par      992  Drama,Family,Music
#
#                                                            Description  \
# Title
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
# Taare Zameen Par     An eight-year-old boy is thought to be a lazy ...
#
#                                              Director  \
# Title
# The Lives of Others  Florian Henckel von Donnersmarck
# Taare Zameen Par                           Aamir Khan
#
#                                                                 Actors  Year  \
# Title
# The Lives of Others  Ulrich Mühe, Martina Gedeck,Sebastian Koch, Ul...  2006
# Taare Zameen Par     Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
#
#                      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  \
# Title
# The Lives of Others                137     8.5  278103               11.28
# ...

# %%
df_small = df[:100]
df_small
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# The Legend of Tarzan      108    Action,Adventure,Drama
# Ex Machina                110      Drama,Mystery,Sci-Fi
# The Belko Experiment      111    Action,Horror,Thriller
# 12 Years a Slave          112   Biography,Drama,History
# 300                       114        Action,Fantasy,War
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
for i in df_small.index :
    print(df_small['Director'][i],df_small['Actors'][i])
# Out:
# James Gunn Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana
# Ridley Scott Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron
# M. Night Shyamalan James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula
# Christophe Lourdelet Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson
# David Ayer Will Smith, Jared Leto, Margot Robbie, Viola Davis
# Yimou Zhang Matt Damon, Tian Jing, Willem Dafoe, Andy Lau
# Damien Chazelle Ryan Gosling, Emma Stone, Rosemarie DeWitt, J.K. Simmons
# James Gray Charlie Hunnam, Robert Pattinson, Sienna Miller, Tom Holland
# Morten Tyldum Jennifer Lawrence, Chris Pratt, Michael Sheen,Laurence Fishburne
# David Yates Eddie Redmayne, Katherine Waterston, Alison Sudol,Dan Fogler
# Theodore Melfi Taraji P. Henson, Octavia Spencer, Janelle Monáe,Kevin Costner
# Gareth Edwards Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen
# Ron Clements Auli'i Cravalho, Dwayne Johnson, Rachel House, Temuera Morrison
# ...

# %%
for index , row in df_small.iterrows() :
    print(row['Director'] , index)
# Out:
# James Gunn Guardians of the Galaxy
# Ridley Scott Prometheus
# M. Night Shyamalan Split
# Christophe Lourdelet Sing
# David Ayer Suicide Squad
# Yimou Zhang The Great Wall
# Damien Chazelle La La Land
# James Gray The Lost City of Z
# Morten Tyldum Passengers
# David Yates Fantastic Beasts and Where to Find Them
# Theodore Melfi Hidden Figures
# Gareth Edwards Rogue One
# Ron Clements Moana
# Nacho Vigalondo Colossal
# Chris Renaud The Secret Life of Pets
# Mel Gibson Hacksaw Ridge
# Paul Greengrass Jason Bourne
# Garth Davis Lion
# Denis Villeneuve Arrival
# Stephen Gaghan Gold
# Kenneth Lonergan Manchester by the Sea
# Walt Dohrn Trolls
# Roland Emmerich Independence Day: Resurgence
# Jon Lucas Bad Moms
# Justin Kurzel Assassin's Creed
# John Hamburg Why Him?
# Tom Ford Nocturnal Animals
# Bryan Singer X-Men: Apocalypse
# Tim Miller Deadpool
# Paul W.S. Anderson Resident Evil: The Final Chapter
# Anthony Russo Captain America: Civil War
# Christopher Nolan Interstellar
# ...

# %%
for index , row in df_small.iterrows() :
    print(row.Actors , row.Metascore)
# Out:
# Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana 76.0
# Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron 65.0
# James McAvoy, Anya Taylor-Joy, Haley Lu Richardson, Jessica Sula 62.0
# Matthew McConaughey,Reese Witherspoon, Seth MacFarlane, Scarlett Johansson 59.0
# Will Smith, Jared Leto, Margot Robbie, Viola Davis 40.0
# Matt Damon, Tian Jing, Willem Dafoe, Andy Lau 42.0
# Ryan Gosling, Emma Stone, Rosemarie DeWitt, J.K. Simmons 93.0
# Charlie Hunnam, Robert Pattinson, Sienna Miller, Tom Holland 78.0
# Jennifer Lawrence, Chris Pratt, Michael Sheen,Laurence Fishburne 41.0
# Eddie Redmayne, Katherine Waterston, Alison Sudol,Dan Fogler 66.0
# Taraji P. Henson, Octavia Spencer, Janelle Monáe,Kevin Costner 74.0
# Felicity Jones, Diego Luna, Alan Tudyk, Donnie Yen 65.0
# Auli'i Cravalho, Dwayne Johnson, Rachel House, Temuera Morrison 81.0
# Anne Hathaway, Jason Sudeikis, Austin Stowell,Tim Blake Nelson 70.0
# ...

# %%
genre_lst = []
for index , row in df.iterrows() :
    genre_lst += row['Genre'].split(',')

# %%
genre_lst
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Horror',
#  'Thriller',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Thriller',
# ...

# %%
from collections import Counter

# %%
Counter(genre_lst).most_common()
# Out:
# [('Drama', 419),
#  ('Action', 277),
#  ('Comedy', 250),
#  ('Adventure', 244),
#  ('Thriller', 148),
#  ('Crime', 126),
#  ('Romance', 120),
#  ('Sci-Fi', 107),
#  ('Fantasy', 92),
#  ('Horror', 87),
#  ('Mystery', 86),
#  ('Biography', 67),
#  ('Family', 48),
#  ('Animation', 45),
#  ('History', 25),
#  ('Music', 15),
#  ('Sport', 15),
#  ('War', 10),
#  ('Musical', 5),
#  ('Western', 4)]

# %%
#testing an assumption that all long movies are good
df['opinion']=df['Rating'].apply(lambda x : "good" if x>= 8 else "boring")

# %%
df
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
df['islong']=df['Runtime (Minutes)'].apply(lambda x : 'Yes' if x > 120 else 'No' )

# %%
df
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
df_new = df[(df['opinion'] ==  "good") & (df['islong'] == 'Yes')]

# %%
df_new.shape
# Out:
# (43, 13)

# %%
#43 movies is long and not boring from 1000 movie the assumption is wrong

# %%
#comparing the relation between how long the movie and how much it is profitable
lng_prf = []
mean = df['Revenue (Millions)'].quantile(.50)
for index , rows in df.iterrows() :
    if (rows['Revenue (Millions)'] >= mean ) & (rows['Runtime (Minutes)'] >= 120 ) :
        lng_prf.append('lng_prfbl')
    elif (rows['Revenue (Millions)'] >= mean) & (rows['Runtime (Minutes)'] < 120 ) :
        lng_prf.append('shrt_prfbl')
    elif (rows['Revenue (Millions)'] < mean) & (rows['Runtime (Minutes)'] < 120 ) :
        lng_prf.append('shrt_notprfbl')  
    elif (rows['Revenue (Millions)'] < mean) & (rows['Runtime (Minutes)'] >= 120 ) :
        lng_prf.append('lng_notprfbl')

# %%
df['lng_prf']=lng_prf

# %%
df
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
df['lng_prf'].value_counts()
#results show that long movies are less but can be profitable more than short movies
# Out:
# lng_prf
# shrt_notprfbl    311
# shrt_prfbl       247
# lng_prfbl        172
# lng_notprfbl     108
# Name: count, dtype: int64

# %%
df['lng_prf'].value_counts(normalize=True)
# Out:
# lng_prf
# shrt_notprfbl    0.371122
# shrt_prfbl       0.294749
# lng_prfbl        0.205251
# lng_notprfbl     0.128878
# Name: proportion, dtype: float64

# %%
df_wide_small = df.filter(items=['Title','Rating','Votes','Metascore'])[:100]

# %%
df_wide_small
# Out:
#                          Rating   Votes  Metascore
# Title
# Guardians of the Galaxy     8.1  757074       76.0
# Prometheus                  7.0  485820       65.0
# Split                       7.3  157606       62.0
# Sing                        7.2   60545       59.0
# Suicide Squad               6.2  393727       40.0
# ...                         ...     ...        ...
# The Legend of Tarzan        6.3  117590       44.0
# Ex Machina                  7.7  339797       78.0
# The Belko Experiment        6.3    3712       44.0
# 12 Years a Slave            8.1  486338       96.0
# 300                         7.7  637104       52.0
#
# [100 rows x 3 columns]

# %%
df_wide_small=df_wide_small.melt( var_name = 'key' , ignore_index=False)

# %%
df_wide_small
#un pivot from wide to long
# Out:
#                                key  value
# Title
# Guardians of the Galaxy     Rating    8.1
# Prometheus                  Rating    7.0
# Split                       Rating    7.3
# Sing                        Rating    7.2
# Suicide Squad               Rating    6.2
# ...                            ...    ...
# The Legend of Tarzan     Metascore   44.0
# Ex Machina               Metascore   78.0
# The Belko Experiment     Metascore   44.0
# 12 Years a Slave         Metascore   96.0
# 300                      Metascore   52.0
#
# [300 rows x 2 columns]
